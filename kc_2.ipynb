# %% [markdown]
# # Import neccessary python packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %% [markdown]
# ## Read in Kansa City Housing Prices .csv dataset
# - dataset found at Kaggle : https://www.kaggle.com/datasets/astronautelvis/kc-house-data

# %%
df = pd.read_csv('/Users/johnchristophersloan/Data Analysis Knowledge Check/assets/kc_final.csv')
df.head(10)
# Out:
#    Unnamed: 0          id        date      price  bedrooms  bathrooms  \
# 0           0  7129300520  2014-10-13   221900.0         3       1.00
# 1           1  6414100192  2014-12-09   538000.0         3       2.25
# 2           2  5631500400  2015-02-25   180000.0         2       1.00
# 3           3  2487200875  2014-12-09   604000.0         4       3.00
# 4           4  1954400510  2015-02-18   510000.0         3       2.00
# 5           5  7237550310  2014-05-12  1225000.0         4       4.50
# 6           6  1321400060  2014-06-27   257500.0         3       2.25
# 7           7  2008000270  2015-01-15   291850.0         3       1.50
# 8           8  2414600126  2015-04-15   229500.0         3       1.00
# 9           9  3793500160  2015-03-12   323000.0         3       2.50
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# ...

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x='sqft_living',
                y='price',
                data=df,
                hue='zipcode',
                s=120)

plt.title('Housing Prices with relation to Square Footage and Zipcode')

plt.show()
